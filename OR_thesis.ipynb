# %%
import pandas as pd
import numpy as np
from pulp import LpProblem, LpVariable, lpSum, lpDot, value, LpBinary

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: C:\Users\somad\OneDrive\Desktop\thesis

# %%
# Change the working directory
new_directory = "C:/Users/somad/OneDrive/Desktop/thesis"
os.chdir(new_directory)

# Verify the change
updated_directory = os.getcwd()
print("Updated Working Directory:", updated_directory)
# Out:
# Updated Working Directory: C:\Users\somad\OneDrive\Desktop\thesis

# %%
from pulp import LpProblem, LpVariable, lpSum, value, LpBinary,  LpMinimize
from geopy.distance import geodesic  # You may need to install the geopy library (pip install geopy)

# %%
# Read data from the Excel sheet
df = pd.read_excel('Customers.xlsx')  # Replace 'your_excel_file.xlsx' with your file name

# %%
df
# Out:
#                                           Name  Latitude_(y)  Longitude_(x)  \
# 0               AKRO_PLASTIC_GmbH_Niederzissen       50.4410         7.2300
# 1                          B_Braun_Bad_Arolsen       51.3794         8.9998
# 2       B_Braun_Melsungen_Schwarzenbergerweg77       51.1397         9.5456
# 3       B_Braun_Melsungen_Schwarzenbergerweg21       51.1372         9.5435
# 4               B_Braun_Melsungen_Carlbraunstr       51.1312         9.5518
# ..                                         ...           ...            ...
# 118                    Volkswagen_Zuffenhausen       48.8358         9.1525
# 119                          Volkswagen_Zwikau       50.7936        12.4875
# 120  Westlake_Vinnolite_Burgkirchen_an_der_Alz       48.1781        12.7228
# 121  Wirthwein_Brandenburg_GmbH_&_Co._KG_Havel       52.3863        12.4261
# 122         ZF_Getriebe_Brandenburg_GmbH_Havel       52.4025        12.5253
#
#          Federal State        Factory Location Cust_Category  Daily_Demand  \
# 0       Rheinlad-Pfalz            Niederzissen           Low      1.626016
# 1                Hesse             Bad Arolsen           Mid      3.252033
# 2                Hesse               Melsungen           Mid      3.252033
# 3                Hesse               Melsungen           Mid      3.252033
# 4                Hesse               Melsungen           Mid      3.252033
# ..                 ...                     ...           ...           ...
# 118  Baden-Württemberg            Zuffenhausen          High      4.878049
# 119             Saxony                  Zwikau          High      4.878049
# 120            Bavaria  Burgkirchen an der Alz           Mid      3.252033
# 121        Brandenburg                   Havel           Low      1.626016
# 122        Brandenburg                   Havel           Low      1.626016
#
#      Fixed_cost
# 0      0.050000
# 1      0.084728
# 2      0.084728
# 3      0.084728
# 4      0.084728
# ..          ...
# 118    0.150125
# 119    0.037672
# 120    0.185273
# 121    0.022029
# 122    0.022029
#
# [123 rows x 8 columns]

# %%
# Function to calculate Euclidean distance between two locations
def euclidean_distance(lat1, lon1, lat2, lon2):
    return np.sqrt((lat1 - lat2)**2 + (lon1 - lon2)**2)

# Set up the PuLP problem
prob = LpProblem("Facility_Location_Model", LpMinimize)

# Decision variables
y = {j: LpVariable(f"y_{j}", 0, 1, LpBinary) for j in df.index}
x = {(i, j): LpVariable(f"x_{i}_{j}", 0, 1, LpBinary) for i in df.index for j in df.index}

# %%
# Objective function
fixed_costs = lpSum(df.at[j, 'Fixed_cost'] * y[j] for j in df.index)
variable_costs = lpSum(df.at[i, 'Daily_Demand'] * euclidean_distance(df.at[i, 'Latitude_(y)'], df.at[i, 'Longitude_(x)'],
                                                                     df.at[j, 'Latitude_(y)'], df.at[j, 'Longitude_(x)']) * x[i, j]
                      for i in df.index for j in df.index)
prob += fixed_costs + variable_costs

# %%
# Constraints
# (1) Open at most 3 stores
prob += lpSum(y[j] for j in df.index) <= 4

# (2) Customers from city 𝑖 can only be assigned to city 𝑗 if a store is opened in city 𝑗
for i in df.index:
    for j in df.index:
        prob += x[i, j] <= y[j]

# (3) Customers from each city are assigned to exactly one store
for i in df.index:
    prob += lpSum(x[i, j] for j in df.index) == 1

# %%
# Solve the problem
prob.solve()

# Print the results
print("Objective Value:", prob.objective.value())
print("\nStore Locations:")
for j in df.index:
    print(f"{df.at[j, 'Name']}: {y[j].value()}")
# Out:
# Objective Value: 399.11706636673955
#
# Store Locations:
# AKRO_PLASTIC_GmbH_Niederzissen: 0.0
# B_Braun_Bad_Arolsen: 0.0
# B_Braun_Melsungen_Schwarzenbergerweg77: 0.0
# B_Braun_Melsungen_Schwarzenbergerweg21: 0.0
# B_Braun_Melsungen_Carlbraunstr: 0.0
# BASF_Ludwigshafen_Gartnereistrase: 0.0
# BASF_Ludwigshafen_Rheinuferstraße: 0.0
# BASF_Ludwigshafen_AmThein: 0.0
# Beiersdorf_GmbH_Berlin: 0.0
# Beiersdorf_Manufacturing_Hamburg_Hamburg: 0.0
# BMW_Group_Berlin: 0.0
# BMW_Group_Dingolfing: 0.0
# BMW_Group_Eisenach: 0.0
# BOSCH_Feuerbach: 0.0
# BOSCH_Leinfelden_Echterdingen: 0.0
# BOSCH_Stuttgart_Pragstraße: 0.0
# BOSCH_Stuttgart_Heilbronnerstr: 0.0
# BOSCH_Stuttgart_Kruppstraße: 0.0
# Brose_GmbH_Berlin: 0.0
# BSN_medical_GmbH_Hamburg: 1.0
# Casar_Drahtseilwerk_Saar_GmbH_Kirkel: 0.0
# Coca_Cola_Berlin: 0.0
# Coca_Cola_Bielefeld: 0.0
# Coca_Cola_Cologne: 0.0
# Coca_Cola_Dorsten: 0.0
# Coca_Cola_Erlangen: 0.0
# Coca_Cola_Fürstenfeldbruck: 0.0
# Coca_Cola_Gemmrigheim: 0.0
# Coca_Cola_Herten: 0.0
# Coca_Cola_Hohenschönhausen: 0.0
# Coca_Cola_Karlsruhe: 0.0
# Coca_Cola_Mannheim: 0.0
# Coca_Cola_Mönchengladbach: 0.0
# Continental_Aachen: 0.0
# Continental_Babenhausen: 0.0
# Continental_Eislingen: 0.0
# Continental_Frankfurt: 0.0
# Continental_Hannover: 0.0
# Continental_Karben: 0.0
# Continental_Korbach: 0.0
# Continental_Regensburg: 0.0
# Continental_Roding: 0.0
# Covestro_Bomlitz: 0.0
# Covestro_Brunsbüttel: 0.0
# Covestro_Krefeld_Uerdingen: 0.0
# Covestro_Leverkusen: 0.0
# Covestro_Markt_Bibart: 0.0
# Covestro_Meppen: 0.0
# Custom_Cells_Itzehoe_GmbH_Itzehoe: 0.0
# Daimler_Sindelfingen: 0.0
# Daimler_Stuttgart: 0.0
# Daimler_Untertürkheim: 0.0
# Dräger_Lübeck: 0.0
# Eaton_Industries_Bad_Ems: 0.0
# Eppendorf_Polymere_GmbH_Wismar: 0.0
# Eppendorf_SE_Hamburg: 0.0
# Evonik_Superabsorber_GmbH_Krefeld: 0.0
# Fresenius_Friedberg_Freseniusstraße: 0.0
# Fresenius_Friedberg_Grünerweg: 0.0
# Hanwag_GmbH_Vierkirchen: 0.0
# Harry_Brot_Gmbh_Schenefeld: 0.0
# Heidelberger_Druckmaschinen_AG_Havel: 0.0
# Henkel_Bopfingen: 0.0
# Henkel_Cologne: 0.0
# Henkel_Hannover: 0.0
# Henkel_Heidelberg: 0.0
# Henkel_Heidenau: 0.0
# Henkel_Krefeld: 0.0
# Henkel_Norderstedt: 0.0
# Henkel_Wassertrüdingen: 0.0
# Henkel_Wehr: 0.0
# Heraeus_Bitterfeld_Wolfen: 0.0
# Heraeus_Dresden: 0.0
# KION_Aschaffenburg: 0.0
# KION_Geisa: 0.0
# KION_Reutlingen: 0.0
# MEDICE_Arzneimittel_Pütter_GmbH_&_Co._KG_Iseerlohn: 0.0
# ml&s_GmbH_&_Co._KG_Greifswald: 0.0
# Müller_Group__Bielefeld: 0.0
# Müller_Group__Düsseldorf: 1.0
# Müller_Group__Fischach: 0.0
# Müller_Group__Freising: 0.0
# Müller_Group__Heinsdorfergrund: 0.0
# Müller_Group__Wachau: 0.0
# Müller_Group__Wilhermsdorf: 0.0
# Novelis_Deutschland_GmbH_Plettenberg: 0.0
# PepsiCo_Rodgau: 0.0
# PlantaCorp_GmbH_Hamburg: 0.0
# Procter_&_Gamble_Altfeld: 0.0
# Procter_&_Gamble_Berlin: 0.0
# Procter_&_Gamble_Crailsheim: 0.0
# Procter_&_Gamble_Euskirchen: 0.0
# Procter_&_Gamble_Gross_Gerau: 0.0
# Procter_&_Gamble_Kronberg: 0.0
# Procter_&_Gamble_Walldürn: 0.0
# Procter_&_Gamble_Worms: 0.0
# Rohde_&_Schwarz_GmbH_&_Co._KG_Teisnach: 0.0
# Rottendorf_Pharma_GmbH_Ennigerloh: 0.0
# SCHOTT_Digitalschmelze_Mainz: 0.0
# Thyssenkrupp_Bochum_EssenerStr: 0.0
# Thyssenkrupp_Duisburg_FranzLenzeStr: 0.0
# Thyssenkrupp_Duisburg: 0.0
# Thyssenkrupp_Finnentrop: 0.0
# Thyssenkrupp_Hagen: 0.0
# Thyssenkrupp_Harz: 0.0
# Thyssenkrupp_Krefeld: 0.0
# Thyssenkrupp_Mühlacker: 0.0
# Thyssenkrupp_Neuhausen_auf_den_Fildern: 0.0
# Thyssenkrupp_Stuttgart: 0.0
# Thyssenkrupp_Weinsberg: 0.0
# Thyssenkrupp_Willich: 0.0
# trans_o_flex_Köln_Hürth: 0.0
# Unilever_Auerbach: 0.0
# Unilever_Buxtehude: 0.0
# Unilever_Heilbronn: 0.0
# Unilever_Heppenheim: 0.0
# Unilever_Manheim: 0.0
# Volkswagen_Neckarsulm: 1.0
# Volkswagen_Zuffenhausen: 0.0
# Volkswagen_Zwikau: 1.0
# Westlake_Vinnolite_Burgkirchen_an_der_Alz: 0.0
# Wirthwein_Brandenburg_GmbH_&_Co._KG_Havel: 0.0
# ZF_Getriebe_Brandenburg_GmbH_Havel: 0.0

# %%
# Print the selected store locations
print("\nSelected Store Locations:")
for j in df.index:
    if y[j].value() == 1.0:
        print(df.at[j, 'Name'])
# Out:
# Selected Store Locations:
# BSN_medical_GmbH_Hamburg
# Müller_Group__Düsseldorf
# Volkswagen_Neckarsulm
# Volkswagen_Zwikau

# %%
# Print the selected store locations with latitude and longitude
print("\nSelected Store Locations:")
for j in df.index:
    if y[j].value() == 1.0:
        name = df.at[j, 'Name']
        latitude = df.at[j, 'Latitude_(y)']
        longitude = df.at[j, 'Longitude_(x)']
        print(f"{name}: Latitude {latitude}, Longitude {longitude}")
# Out:
# Selected Store Locations:
# BSN_medical_GmbH_Hamburg: Latitude 53.4762, Longitude 9.9069
# Müller_Group__Düsseldorf: Latitude 51.1674, Longitude 6.843
# Volkswagen_Neckarsulm: Latitude 49.2014, Longitude 9.2219
# Volkswagen_Zwikau: Latitude 50.7936, Longitude 12.4875

# %%
# Solve the problem
prob.solve()

# Print the results
print("Objective Value:", prob.objective.value())
print("\nStore Locations:")
for j in df.index:
    if y[j].value() == 1.0:
        print(f"{df.at[j, 'Name']} ({df.at[j, 'Latitude_(y)']}, {df.at[j, 'Longitude_(x)']}):")
        for i in df.index:
            if x[i, j].value() == 1.0:
                print(f"   {df.at[i, 'Name']}")
# Out:
# Objective Value: 399.11706636673955
#
# Store Locations:
# BSN_medical_GmbH_Hamburg (53.4762, 9.9069):
#    Beiersdorf_Manufacturing_Hamburg_Hamburg
#    BSN_medical_GmbH_Hamburg
#    Continental_Hannover
#    Covestro_Bomlitz
#    Covestro_Brunsbüttel
#    Custom_Cells_Itzehoe_GmbH_Itzehoe
#    Dräger_Lübeck
#    Eppendorf_Polymere_GmbH_Wismar
#    Eppendorf_SE_Hamburg
#    Harry_Brot_Gmbh_Schenefeld
#    Henkel_Hannover
#    Henkel_Norderstedt
#    PlantaCorp_GmbH_Hamburg
#    Thyssenkrupp_Harz
#    Unilever_Buxtehude
# Müller_Group__Düsseldorf (51.1674, 6.843):
#    AKRO_PLASTIC_GmbH_Niederzissen
#    B_Braun_Bad_Arolsen
#    Casar_Drahtseilwerk_Saar_GmbH_Kirkel
#    Coca_Cola_Bielefeld
#    Coca_Cola_Cologne
#    Coca_Cola_Dorsten
#    Coca_Cola_Herten
#    Coca_Cola_Mönchengladbach
#    Continental_Aachen
#    Continental_Korbach
#    Covestro_Krefeld_Uerdingen
#    Covestro_Leverkusen
#    Covestro_Meppen
#    Eaton_Industries_Bad_Ems
#    Evonik_Superabsorber_GmbH_Krefeld
#    Henkel_Cologne
#    Henkel_Krefeld
#    MEDICE_Arzneimittel_Pütter_GmbH_&_Co._KG_Iseerlohn
#    Müller_Group__Bielefeld
#    Müller_Group__Düsseldorf
#    Novelis_Deutschland_GmbH_Plettenberg
#    Procter_&_Gamble_Euskirchen
#    Rottendorf_Pharma_GmbH_Ennigerloh
#    Thyssenkrupp_Bochum_EssenerStr
#    Thyssenkrupp_Duisburg_FranzLenzeStr
#    Thyssenkrupp_Duisburg
#    Thyssenkrupp_Finnentrop
#    Thyssenkrupp_Hagen
#    Thyssenkrupp_Krefeld
#    Thyssenkrupp_Willich
#    trans_o_flex_Köln_Hürth
# Volkswagen_Neckarsulm (49.2014, 9.2219):
#    B_Braun_Melsungen_Schwarzenbergerweg77
#    B_Braun_Melsungen_Schwarzenbergerweg21
#    B_Braun_Melsungen_Carlbraunstr
#    BASF_Ludwigshafen_Gartnereistrase
#    BASF_Ludwigshafen_Rheinuferstraße
#    BASF_Ludwigshafen_AmThein
#    BMW_Group_Eisenach
#    BOSCH_Feuerbach
#    BOSCH_Leinfelden_Echterdingen
#    BOSCH_Stuttgart_Pragstraße
#    BOSCH_Stuttgart_Heilbronnerstr
#    BOSCH_Stuttgart_Kruppstraße
#    Coca_Cola_Erlangen
#    Coca_Cola_Fürstenfeldbruck
#    Coca_Cola_Gemmrigheim
#    Coca_Cola_Karlsruhe
#    Coca_Cola_Mannheim
#    Continental_Babenhausen
#    Continental_Eislingen
#    Continental_Frankfurt
#    Continental_Karben
#    Covestro_Markt_Bibart
#    Daimler_Sindelfingen
#    Daimler_Stuttgart
#    Daimler_Untertürkheim
#    Fresenius_Friedberg_Freseniusstraße
#    Fresenius_Friedberg_Grünerweg
#    Hanwag_GmbH_Vierkirchen
#    Henkel_Bopfingen
#    Henkel_Heidelberg
#    Henkel_Wassertrüdingen
#    Henkel_Wehr
#    KION_Aschaffenburg
#    KION_Reutlingen
#    Müller_Group__Fischach
#    Müller_Group__Wilhermsdorf
#    PepsiCo_Rodgau
#    Procter_&_Gamble_Altfeld
#    Procter_&_Gamble_Crailsheim
#    Procter_&_Gamble_Gross_Gerau
#    Procter_&_Gamble_Kronberg
#    Procter_&_Gamble_Walldürn
#    Procter_&_Gamble_Worms
#    SCHOTT_Digitalschmelze_Mainz
#    Thyssenkrupp_Mühlacker
#    Thyssenkrupp_Neuhausen_auf_den_Fildern
#    Thyssenkrupp_Stuttgart
#    Thyssenkrupp_Weinsberg
#    Unilever_Heilbronn
#    Unilever_Heppenheim
#    Unilever_Manheim
#    Volkswagen_Neckarsulm
#    Volkswagen_Zuffenhausen
# Volkswagen_Zwikau (50.7936, 12.4875):
#    Beiersdorf_GmbH_Berlin
#    BMW_Group_Berlin
#    BMW_Group_Dingolfing
#    Brose_GmbH_Berlin
#    Coca_Cola_Berlin
#    Coca_Cola_Hohenschönhausen
#    Continental_Regensburg
#    Continental_Roding
#    Heidelberger_Druckmaschinen_AG_Havel
#    Henkel_Heidenau
#    Heraeus_Bitterfeld_Wolfen
#    Heraeus_Dresden
#    KION_Geisa
#    ml&s_GmbH_&_Co._KG_Greifswald
#    Müller_Group__Freising
#    Müller_Group__Heinsdorfergrund
#    Müller_Group__Wachau
#    Procter_&_Gamble_Berlin
#    Rohde_&_Schwarz_GmbH_&_Co._KG_Teisnach
#    Unilever_Auerbach
#    Volkswagen_Zwikau
#    Westlake_Vinnolite_Burgkirchen_an_der_Alz
#    Wirthwein_Brandenburg_GmbH_&_Co._KG_Havel
#    ZF_Getriebe_Brandenburg_GmbH_Havel

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\somad\anaconda3\lib\site-packages (5.18.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\somad\anaconda3\lib\site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in c:\users\somad\anaconda3\lib\site-packages (from plotly) (20.4)
# Requirement already satisfied: six in c:\users\somad\anaconda3\lib\site-packages (from packaging->plotly) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\somad\anaconda3\lib\site-packages (from packaging->plotly) (2.4.7)

# %%
# !pip install plotly.express
# Out:
# Requirement already satisfied: plotly.express in c:\users\somad\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: plotly>=4.1.0 in c:\users\somad\anaconda3\lib\site-packages (from plotly.express) (5.18.0)
# Requirement already satisfied: numpy>=1.11 in c:\users\somad\anaconda3\lib\site-packages (from plotly.express) (1.19.2)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\somad\anaconda3\lib\site-packages (from plotly.express) (1.1.3)
# Requirement already satisfied: patsy>=0.5 in c:\users\somad\anaconda3\lib\site-packages (from plotly.express) (0.5.1)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\somad\anaconda3\lib\site-packages (from plotly.express) (0.12.0)
# Requirement already satisfied: scipy>=0.18 in c:\users\somad\anaconda3\lib\site-packages (from plotly.express) (1.10.1)
# Requirement already satisfied: packaging in c:\users\somad\anaconda3\lib\site-packages (from plotly>=4.1.0->plotly.express) (20.4)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\somad\anaconda3\lib\site-packages (from plotly>=4.1.0->plotly.express) (8.2.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\somad\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly.express) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\somad\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly.express) (2020.1)
# Requirement already satisfied: six in c:\users\somad\anaconda3\lib\site-packages (from patsy>=0.5->plotly.express) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\somad\anaconda3\lib\site-packages (from packaging->plotly>=4.1.0->plotly.express) (2.4.7)

# %%
import plotly.express as px

# %%
import pandas as pd
import plotly.express as px

# Your DataFrame with all 123 locations
df1 = pd.read_excel('Customers.xlsx')  # Replace 'your_file.xlsx' with your actual file path

# Specify colors for each Cust_Category
color_discrete_map = {'Low': 'green', 'Mid': 'orange', 'High': 'red'}

# Illustrate input data via Plotly Express
fig = px.scatter_mapbox(
    df1,
    lat='Latitude_(y)',
    lon='Longitude_(x)',
    color='Cust_Category',  # Color based on Cust_Category
    color_discrete_map=color_discrete_map,
    zoom=10,
    mapbox_style='open-street-map',
    width=1000,
    height=1000
)
fig.update_traces(marker={'size': 8})  # Adjust the size as needed
fig.show()
# Out:
# <div>                            <div id="0509a103-103d-4682-b0c6-73c6631c10e5" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0509a103-103d-4682-b0c6-73c6631c10e5")) {                    Plotly.newPlot(                        "0509a103-103d-4682-b0c6-73c6631c10e5",                        [{"hovertemplate":"Cust_Category=Low\u003cbr\u003eLatitude_(y)=%{lat}\u003cbr\u003eLongitude_(x)=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[50.441,52.5177,49.3092,53.9557,51.3201,48.3571,53.6049,54.0798,53.5457,49.8292,51.8424,50.8565,52.3863,52.4025],"legendgroup":"Low","lon":[7.23,13.3256,7.2757,9.4865,6.5841,11.4433,9.8358,13.3758,10.0088,9.5417,8.0367,6.8404,12.4261,12.5253],"marker":{"color":"green","size":8},"mode":"markers","name":"Low","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Cust_Category=Mid\u003cbr\u003eLatitude_(y)=%{lat}\u003cbr\u003eLongitude_(x)=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[51.3794,51.1397,51.1372,51.1312,49.5093,49.4919,49.4943,53.5837,48.8225,48.6981,48.8097,48.8199,48.8145,52.5319,53.4762,52.5008,52.015,50.9747,51.6605,49.5562,48.1603,49.0197,51.5969,52.5668,49.0669,49.5132,51.1209,50.8334,49.9725,48.6915,50.1359,52.4064,50.2254,51.2896,49.0111,49.1893,52.9113,53.902,51.3687,51.0147,49.6471,52.6676,53.8369,50.3201,53.8755,53.6487,52.4416,48.8614,50.9896,52.3756,49.4093,50.988,51.3409,53.7252,49.0446,47.6087,49.9495,50.4225,48.5612,51.3836,51.9906,51.1674,48.3097,48.3795,50.6022,51.1519,49.4885,51.2336,52.4639,49.1295,50.6958,49.9294,50.1705,49.5712,49.6605,49.0301,50.0134,51.4734,51.4913,51.4832,51.1681,51.3454,51.8793,51.3263,48.9518,48.6812,48.7575,49.1513,51.278,50.5074,53.4644,49.1316,49.6359,49.4422,48.1781],"legendgroup":"Mid","lon":[8.9998,9.5456,9.5435,9.5518,8.4176,8.4394,8.4299,9.9609,9.1613,9.1445,9.1958,9.1758,9.1706,13.3181,9.9069,13.452,8.5831,6.8925,7.0115,11.001,11.2214,9.1664,7.134,13.5369,8.3718,8.5575,6.4368,6.0186,8.9513,9.7164,8.5947,9.7312,8.7605,8.8723,12.1418,12.5368,9.6399,9.185,6.6626,6.9872,10.4388,7.2017,10.6584,7.7399,11.4206,10.0622,12.5351,10.3544,6.8908,9.6838,8.6466,13.8468,6.6718,9.9928,10.6097,7.9122,9.1042,10.7512,9.2455,7.6667,8.4897,6.843,10.6493,11.7317,12.3209,13.9761,10.7191,7.8393,13.4077,10.0305,6.8251,8.495,8.5302,9.3615,8.3588,12.999,8.2471,7.1714,6.7477,6.7199,7.971,7.5865,10.7096,6.683,8.8682,9.2549,9.2635,9.2718,6.514,12.4054,9.7155,9.2126,8.6158,8.5102,12.7228],"marker":{"color":"orange","size":8},"mode":"markers","name":"Mid","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Cust_Category=High\u003cbr\u003eLatitude_(y)=%{lat}\u003cbr\u003eLongitude_(x)=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[52.5453,48.6484,51.0107,48.7008,48.7876,48.7876,50.3193,50.3242,51.6397,51.0385,49.9914,49.2014,48.8358,50.7936],"legendgroup":"High","lon":[13.2282,12.4655,10.2594,8.9802,9.2437,9.237,8.7592,8.7431,12.302,13.8013,8.8704,9.2219,9.1525,12.4875],"marker":{"color":"red","size":8},"mode":"markers","name":"High","showlegend":true,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201 ...

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# Your DataFrame with all 123 locations
df1 = pd.read_excel('Customers.xlsx')  # Replace 'your_file.xlsx' with your actual file path

# Create a new column 'Facility' to label the facilities
df1['Facility'] = df1.apply(lambda row: 'Facility' if y[row.name].value() == 1.0 else 'Not Facility', axis=1)

# Illustrate the results via Plotly Express
fig = px.scatter_mapbox(
    df1,
    lat='Latitude_(y)',
    lon='Longitude_(x)',
    color='Facility',
    zoom=10,
    mapbox_style='open-street-map',
    width=1000,
    height=1000
)

# Add labels for facilities and their assigned customers
for j in df.index:
    if y[j].value() == 1.0:
        facility_name = df.at[j, 'Name']
        assigned_customers = [df.at[i, 'Name'] for i in df.index if x[i, j].value() == 1.0]
        facility_label = f"{facility_name}\nAssigned Customers: {', '.join(assigned_customers)}"
        fig.add_annotation(
            go.layout.Annotation(
                text=facility_label,
                x=df.at[j, 'Longitude_(x)'],
                y=df.at[j, 'Latitude_(y)'],
                showarrow=True,
                arrowhead=2,
                arrowcolor="black",
                arrowwidth=3,
                ax=0,
                ay=-40
            )
        )

fig.update_traces(marker={'size': 8})  # Adjust the size as needed
fig.show()
# Out:
# <div>                            <div id="8f3b6d89-1e11-4e1f-bcfb-60a564d410c3" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f3b6d89-1e11-4e1f-bcfb-60a564d410c3")) {                    Plotly.newPlot(                        "8f3b6d89-1e11-4e1f-bcfb-60a564d410c3",                        [{"hovertemplate":"Facility=Not Facility\u003cbr\u003eLatitude_(y)=%{lat}\u003cbr\u003eLongitude_(x)=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[50.441,51.3794,51.1397,51.1372,51.1312,49.5093,49.4919,49.4943,52.5177,53.5837,52.5453,48.6484,51.0107,48.8225,48.6981,48.8097,48.8199,48.8145,52.5319,49.3092,52.5008,52.015,50.9747,51.6605,49.5562,48.1603,49.0197,51.5969,52.5668,49.0669,49.5132,51.1209,50.8334,49.9725,48.6915,50.1359,52.4064,50.2254,51.2896,49.0111,49.1893,52.9113,53.902,51.3687,51.0147,49.6471,52.6676,53.9557,48.7008,48.7876,48.7876,53.8369,50.3201,53.8755,53.6487,51.3201,50.3193,50.3242,48.3571,53.6049,52.4416,48.8614,50.9896,52.3756,49.4093,50.988,51.3409,53.7252,49.0446,47.6087,51.6397,51.0385,49.9495,50.4225,48.5612,51.3836,54.0798,51.9906,48.3097,48.3795,50.6022,51.1519,49.4885,51.2336,49.9914,53.5457,49.8292,52.4639,49.1295,50.6958,49.9294,50.1705,49.5712,49.6605,49.0301,51.8424,50.0134,51.4734,51.4913,51.4832,51.1681,51.3454,51.8793,51.3263,48.9518,48.6812,48.7575,49.1513,51.278,50.8565,50.5074,53.4644,49.1316,49.6359,49.4422,48.8358,48.1781,52.3863,52.4025],"legendgroup":"Not Facility","lon":[7.23,8.9998,9.5456,9.5435,9.5518,8.4176,8.4394,8.4299,13.3256,9.9609,13.2282,12.4655,10.2594,9.1613,9.1445,9.1958,9.1758,9.1706,13.3181,7.2757,13.452,8.5831,6.8925,7.0115,11.001,11.2214,9.1664,7.134,13.5369,8.3718,8.5575,6.4368,6.0186,8.9513,9.7164,8.5947,9.7312,8.7605,8.8723,12.1418,12.5368,9.6399,9.185,6.6626,6.9872,10.4388,7.2017,9.4865,8.9802,9.2437,9.237,10.6584,7.7399,11.4206,10.0622,6.5841,8.7592,8.7431,11.4433,9.8358,12.5351,10.3544,6.8908,9.6838,8.6466,13.8468,6.6718,9.9928,10.6097,7.9122,12.302,13.8013,9.1042,10.7512,9.2455,7.6667,13.3758,8.4897,10.6493,11.7317,12.3209,13.9761,10.7191,7.8393,8.8704,10.0088,9.5417,13.4077,10.0305,6.8251,8.495,8.5302,9.3615,8.3588,12.999,8.0367,8.2471,7.1714,6.7477,6.7199,7.971,7.5865,10.7096,6.683,8.8682,9.2549,9.2635,9.2718,6.514,6.8404,12.4054,9.7155,9.2126,8.6158,8.5102,9.1525,12.7228,12.4261,12.5253],"marker":{"color":"#636efa","size":8},"mode":"markers","name":"Not Facility","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Facility=Facility\u003cbr\u003eLatitude_(y)=%{lat}\u003cbr\u003eLongitude_(x)=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[53.4762,51.1674,49.2014,50.7936],"legendgroup":"Facility","lon":[9.9069,6.843,9.2219,12.4875],"marker":{"color":"#EF553B","size":8},"mode":"markers","name":"Facility","showlegend":true,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"tick ...

# %%
import folium
from IPython.display import display

# Create a map centered at the average latitude and longitude
center_lat = df['Latitude_(y)'].mean()
center_lon = df['Longitude_(x)'].mean()
mymap = folium.Map(location=[center_lat, center_lon], zoom_start=6)

# Create a map with custom width and height
mymap = folium.Map(location=[center_lat, center_lon], zoom_start=6, width=1000, height=800)



## Add markers for facility locations
for j in df.index:
    if y[j].value() == 1.0:
        folium.Marker(
            location=[df.at[j, 'Latitude_(y)'], df.at[j, 'Longitude_(x)']],
            popup=df.at[j, 'Name'],
            icon=folium.Icon(color='blue')
        ).add_to(mymap)

# Add markers for customer locations and lines connecting customers to their assigned facility
for j in df.index:
    if y[j].value() == 1.0:
        for i in df.index:
            if x[i, j].value() == 1.0:
                folium.Marker(
                    location=[df.at[i, 'Latitude_(y)'], df.at[i, 'Longitude_(x)']],
                    popup=df.at[i, 'Name'],
                    icon=folium.Icon(color='green', icon_size=(20,20))
                ).add_to(mymap)
                folium.PolyLine(
                    locations=[[df.at[i, 'Latitude_(y)'], df.at[i, 'Longitude_(x)']],
                               [df.at[j, 'Latitude_(y)'], df.at[j, 'Longitude_(x)']]],
                    color='red'
                ).add_to(mymap)

# Display the map in the notebook
display(mymap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67befe152a8abdab1a96c95277bc6a15 {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 800.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67befe152a8abdab1a96c95277bc6a15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67befe152a8abdab1a96c95277bc6a15 = L.map(
#                 &quot;map_67befe152a8abdab1a96c95277bc6a15&quot;,
#                 {
#                     center: [50.6670512195122, 9.544824390243903],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66f2ea3472268140d5f10db693ace476 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_67befe152a8abdab1a96c95277bc6a15);
#
#
#             var marker_3d46c5fd063a60d27bc45cea702833b9 = L.marker(
#                 [53.4762, 9.9069],
#                 {}
#             ).addTo(map_67befe152a8abdab1a96c95277bc6a15);
#
#
#             var icon_9a2c72b0c31cbf8d2016c65b8cf2dd46 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3d46c5fd063a60d27bc45cea702833b9.setIcon(icon_9a2c72b0c31cbf8d2016c65b8cf2dd46);
#
#
#         var popup_9163eb6bd9356bda79348de9f53e6e68 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b640fedbf1a8bece6e754698442b603 = $(`&lt;div id=&quot;html_6b640fedbf1a8bece6e754698442b603&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BSN_medical_GmbH_Hamburg&lt;/div&gt;`)[0];
#                 popup_9163eb6bd9356bda79348de9f53e6e68.setContent(html_6b640fedbf1a8bece6e754698442b603);
#
#
#
#         marker_3d46c5fd063a60d27bc45cea702833b9.bindPopup(popup_9163eb6bd9356bda79348de9f53e6e68)
#         ;
#
#
#
#
#             var marker_4ec5c45819971b650ba15e3b450736aa = L.marker(
#                 [51.1674, 6.843],
#                 {}
#             ).addTo(map_67befe152a8abdab1a96c95277bc6a15);
#
#
#             var icon_c7f39e6b15b7e7e9805f8fb41173cebf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4ec5c45819971b650ba15e3b450736aa.setIcon(icon_c7f39e6b15b7e7e9805f8fb41173cebf);
#
#
#         var popup_a89e49a5ff90d8d0958242a92c801c6d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b24993217fc8cc1fd1cb39af729dabb5 = $(`&lt;div id=&quot;html_b24993217fc8cc1fd1cb39af729dabb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Müller_Group__Düsseldorf&lt;/div&gt;`)[0];
#                 popup_a89e49a5ff90d8d0958242a92c801c6d.setContent(html_b24993217fc8cc1fd1cb39af729dabb5);
#
#
#
#         marker_4ec5c45819971b650ba15e3b450736aa.bindPopup(popup_a89e49a5ff90d8d0958242a92c801c6d)
#         ;
#
#
#
#
#             var marker_a9529645b3c73f70bfd05c7833d06d29 = L.marker(
#                 [49.2014, 9.2219],
#                 {}
#             ).addTo(map_67befe152a8abdab1a96c95277bc6a15);
#
#
#             var icon_4dce3d6922e052def655c9d22ff2e363 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a9529645b3c73f70bfd05c7833d06d29.setIcon(icon_4dce3d6922e052def655c9d22ff2e363);
#
#
#         var popup_6fae9394c119c8d8a3dbcb3c014404a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ca006402e469cdf0283b91a7ee186686 = $(`&lt;div id=&quot;html_ca006402e469cdf0283b91a7ee186686&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Volkswagen_Neckarsulm&lt;/div&gt;`)[0];
#                 popup_6fae9394c119c8d8a3dbcb3c014404a2.setContent(html_ca006402e469cdf0283b91a7ee186686);
#
#
#
#         marker_a9529645b3c73f70bfd05c7833d06d29.bindPopup(popup_6fae9394c119c8d8a3dbcb3c014404a2)
#         ;
#
#
#
#
#             var marker_277cda3247b93a1e19e4fb7c4a1d3310 = L.marker(
#                 [50.7936, 12.4875],
#                 {}
#             ).addTo(map_67befe152a8abdab1a96c95277bc6a15);
#
#
#             var icon_0c9c537f618509283010af5824bdfc35 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
